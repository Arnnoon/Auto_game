# %%
# LD player 9.0.69
# 1920x1080 (dpi 280)
pip install -r requirements.txt

# %%
from re import X
from pyautogui import *
import pyautogui
import time
import keyboard #{'alt', 'alt gr', 'ctrl', 'left alt', 'left ctrl', 'left shift', 'left windows', 'right alt', 'right ctrl', 'right shift', 'right windows', 'shift', 'windows'}
import random
import win32api, win32con

# click :)
def click(x, y):
    original_x, original_y = win32api.GetCursorPos()
    win32api.SetCursorPos((x, y))
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTDOWN, 0, 0)
    time.sleep(0.01)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTUP, 0, 0)
    win32api.SetCursorPos((original_x, original_y))

def dragclick(x1, y1, x2, y2):
    original_x, original_y = win32api.GetCursorPos()
    win32api.SetCursorPos((x1, y1))
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTDOWN, 0, 0)
    time.sleep(0.1)
    win32api.SetCursorPos((x2, y2))
    time.sleep(0.1)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTUP, 0, 0)
    win32api.SetCursorPos((original_x, original_y))

# continuous click
def continuousclick():
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            x, y = pyautogui.position()
            click(x, y)

# return color value(r, g, b) of pixel
def checkcolor(x, y):
    pic = pyautogui.screenshot(region = (0,0,1919,1079))
    r, g, b = pic.getpixel((x, y))
    return r, g, b

# print position and color value(r, g, b) of given position
def checkPosition(x, y):
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            r, g ,b = checkcolor(x, y)
            print(f"# x,y ({x}, {y})   r,g,b ({r}, {g}, {b})\t\tif checkcolor({x}, {y}) == ({r}, {g}, {b}):")
    return 1

# print position and color value(r, g, b) of mouse position
def checkClick():
    x1 = y1 = x2 = y2 = -1
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            x, y = pyautogui.position()
            r, g, b = checkcolor(x, y)
            print(f"# x,y ({x}, {y})   r,g,b ({r}, {g}, {b})\twhile not checkcolor({x}, {y}) == ({r}, {g}, {b}):")
            print(f"""'': {{'pos': ({x}, {y}), 'color': ({r}, {g}, {b})}}""")
            # print(f"# x,y ({x}, {y})   r,g,b ({r}, {g}, {b})\tif checkcolor({x}, {y}) == ({r}, {g}, {b}):")
            time.sleep(0.1)
        elif(keyboard.is_pressed('a') == True):
            x1, y1 = pyautogui.position()
        elif(keyboard.is_pressed('d') == True):
            x2, y2 = pyautogui.position()

        if x1 != -1 and y1 != -1 and x2 != -1 and y2 != -1:
            print(f"# x1,y1 ({x1}, {y1})  x2,y2 ({x2}, {y2})\trandclick({x1}, {y1}, {x2}, {y2})")
            print(f"""'': {{'area': (({x1}, {y1}), ({x2}, {y2}))}}""")

            x1 = y1 = x2 = y2 = -1
            time.sleep(0.1)
    return 1

# return a random pixel position from given area
def randomarea(x1, y1, x2, y2):
    center_x = (x1 + x2) / 2
    center_y = (y1 + y2) / 2
    max_radius_x = center_x - x1
    max_radius_y = center_y - y1
    x_scale = random.uniform(-1, 1)
    x_scale = x_scale * abs(x_scale)
    y_scale = random.uniform(-1, 1)
    y_scale = y_scale * abs(x_scale)
    xx = int(center_x + (x_scale * max_radius_x))
    yy = int(center_y + (y_scale * max_radius_y))
    return xx, yy

# random click from given area
def randclick(x1, y1, x2, y2):
    x, y = randomarea(x1, y1, x2, y2)
    click(x, y)
    return x, y

# timesleep for input time + 0-1 sec
def randtimesleep(inputtime):
    pm5 = random.random() * random.random()
    randtime = pm5 + inputtime
    time.sleep(randtime)

def exitgame():
    win32api.SetCursorPos((1870, 27))
    time.sleep(0.5)    
    # x,y (1862, 25)   r,g,b (255, 71, 51)	
    if checkcolor(1862, 25) == (255, 71, 51):
        # x1,y1 (1852, 5)  x2,y2 (1872, 28)	
        randclick(1852, 5, 1872, 28)
        time.sleep(0.5)
        # x1,y1 (975, 568)  x2,y2 (1058, 588)	
        randclick(975, 568, 1058, 588)
    
    
def autoRTA(times):
    x = 0
    y = 0
    round = 0
    print("autoRTA will start in 3 sec")
    time.sleep(3)
    print("autoRTA is starting")
    if times == 0:
        times = 999999
    start_time = time.strftime("%H:%M:%S", time.localtime())
    while keyboard.is_pressed('left alt') == False:
        if times < round:
            break
        # x,y (1564, 480)   r,g,b (237, 227, 183)	
        if checkcolor(1564, 480) == (237, 227, 183):
            round += 1
            print("round " + str(round))
            randtimesleep(1)
            # x1,y1 (1419, 442)  x2,y2 (1742, 542)	
            x, y = randclick(1419, 442, 1742, 542)
            print('\tfindmatch\tclick(' + str(x) + ', ' + str(y) + ')')	
            randtimesleep(1)
            # x,y (779, 397)   r,g,b (209, 180, 119)	
            if checkcolor(779, 397) == (209, 180, 119):
                round -= 1
                print("\tout of RTA ticket")
                print("finished auto rta")
                # x1,y1 (831, 595)  x2,y2 (1041, 672)	
                randclick(831, 595, 1041, 672)
                break
            time.sleep(60)
            while keyboard.is_pressed('left alt') == False:
                # x,y (245, 964)   r,g,b (255, 255, 255)	
                if checkcolor(245, 964) == (255, 255, 255):
                    print("\tgive up \tFALSE")
                    randtimesleep(1)
                    # x1,y1 (224, 937)  x2,y2 (273, 990)	
                    randclick(224, 937, 273, 990)
                    print('\tautoplay\tclick(' + str(x) + ', ' + str(y) + ')')
                    while True:
                        # x,y (362, 772)   r,g,b (201, 105, 19)	
                        if checkcolor(362, 772) in ((201, 105, 19), (200, 105, 20)):
                            randtimesleep(1)
                            # x1,y1 (1314, 715)  x2,y2 (285, 998)	
                            x, y = randclick(1314, 715, 285, 998)
                            print('\tmatchfinish\tclick(' + str(x) + ', ' + str(y) + ')')
                            break
                        else:
                            time.sleep(5)
                    break
                # x,y (897, 615)   r,g,b (248, 233, 173)
                elif checkcolor(897, 615) == (248, 233, 173):
                    print("\tgive up \tTRUE")
                    randtimesleep(1)
                    # x1,y1 = (880, 595)   x2,y2 = (1004, 671)
                    x, y = randclick(880, 595, 1004, 671)
                    break
        randtimesleep(1)    
        
    finish_time = time.strftime("%H:%M:%S", time.localtime())
    print("\n" + str(round) + " rounds")
    print("start time:\t", start_time)
    print("finish time:\t", finish_time)
    exitgame()


def autoRTAsl(times):
    x = 0
    y = 0
    round = 0
    print("auto Special League RTA will start in 3 sec")
    time.sleep(3)
    print("auto Special League RTA is starting")
    if times == 0:
        times = 999999
    start_time = time.strftime("%H:%M:%S", time.localtime())
    while keyboard.is_pressed('left alt') == False:
        if times < round:
            break
        # x,y (1269, 842)   r,g,b (242, 143, 15)		
        if checkcolor(1269, 842) == (242, 142, 15):
            round += 1
            print("round " + str(round))
            randtimesleep(1)
            # x1,y1 (1262, 834)  x2,y2 (1604, 937)
            x, y = randclick(1262, 834, 1604, 937)
            print('\tfindmatch\tclick(' + str(x) + ', ' + str(y) + ')')	
            randtimesleep(1)
            # x,y (779, 397)   r,g,b (209, 180, 119)	
            if checkcolor(779, 397) == (209, 180, 119):
                round -= 1
                print("\tout of RTA ticket")
                print("finished auto rta")
                # x1,y1 = (861, 594)   x2,y2 = (1017, 674)
                x, y = randclick(861, 594, 1017, 674)
                break
            # time.sleep(60)
            while keyboard.is_pressed('left alt') == False:
                # # Ban Oliver!!!
                # # x,y (297, 172)   r,g,b (210, 69, 38)
                # if checkcolor(297, 172) == (210, 69, 38):
                #     print("\tBan Oliver")
                #     randtimesleep(1)
                #     # x1,y1 (1576, 550)  x2,y2 (1622, 586)
                #     x, y = randclick(1576, 550, 1622, 586)
                #     randtimesleep(1)
                #     # x1,y1 (1385, 779)  x2,y2 (1493, 877)	
                #     randclick(1385, 779, 1493, 877)
                #     randtimesleep(1)
                #     # x1,y1 (828, 935)  x2,y2 (1059, 1000)
                #     x, y = randclick(828, 935, 1059, 1000)
                #     time.sleep(60)
                # # End ban Oliver section
                # x,y (245, 964)   r,g,b (255, 255, 255)	
                if checkcolor(245, 964) == (255, 255, 255):
                    print("\tgive up \tFALSE")
                    randtimesleep(1)
                    # x1,y1 (224, 937)  x2,y2 (273, 990)	
                    randclick(224, 937, 273, 990)
                    print('\tautoplay\tclick(' + str(x) + ', ' + str(y) + ')')
                    while True:
                        # x,y (362, 772)   r,g,b (236, 180, 80)		
                        if checkcolor(362, 772) == (236, 180, 80):
                            randtimesleep(1)
                            # x1,y1 (1314, 715)  x2,y2 (285, 998)	
                            x, y = randclick(1314, 715, 285, 998)
                            print('\tmatchfinish\tclick(' + str(x) + ', ' + str(y) + ')')
                            break
                        else:
                            time.sleep(5)
                    break
                # x,y (897, 615)   r,g,b (248, 233, 173)
                elif checkcolor(897, 615) == (248, 233, 173):
                    print("\tgive up \tTRUE")
                    randtimesleep(1)
                    # x1,y1 = (880, 595)   x2,y2 = (1004, 671)
                    x, y = randclick(880, 595, 1004, 671)
                    break
        randtimesleep(1)    
        
    finish_time = time.strftime("%H:%M:%S", time.localtime())
    print("\n" + str(round) + " rounds")
    print("start time:\t", start_time)
    print("finish time:\t", finish_time)
    exitgame()


def autoTOA():
    x = 0
    y = 0
    boss = 0
    print("autoTOA will start in 3 sec")
    time.sleep(3)
    print("autoTOA is starting")
    while keyboard.is_pressed('left alt') == False:
        boss = 0
        # x,y (1554, 764)   r,g,b (241, 226, 167)
        if checkcolor(1554, 764) == (241, 226, 167):
            # x1,y1 = (1433, 682)   x2,y2 = (1675, 793)
            x, y = randclick(1433, 682, 1675, 793)
            print('start state\t\tclick(' + str(x) + ', ' + str(y) + ')')
            print("\tloading...")
            randtimesleep(6)
            # x,y (383, 962)    r,g,b (255, 255, 255)
            if checkcolor(383, 962) == (255, 255, 255):
                randtimesleep(1)
                # x1,y1 = (345, 925)   x2,y2 = (424, 998)
                x, y = randclick(345, 925, 424, 998)
                print('\tauto FALSE\tclick(' + str(x) + ', ' + str(y) + ')')
            else:
                print("\tauto TRUE")
            randtimesleep(0.5)
            while True:
                # x,y (947, 56)    r,g,b (253, 253, 68)
                r,g,b = checkcolor(947, 56)
                if r > 230 and g > 230 and b < 75 and boss == 0:
                    randtimesleep(1)
                    # x1,y1 = (909, 292)   x2,y2 = (973, 519)
                    x, y = randclick(909, 292, 973, 519)
                    print("\tboss battle")
                    boss = 1
                # x,y (1432, 535)   r,g,b (234, 42, 94)
                if checkcolor(1432, 535) == (234, 42, 94):
                    randtimesleep(0.5)
                    # x1,y1 = (1352, 473)   x2,y2 = (1536, 596)
                    x, y = randclick(1352, 473, 1536, 596)
                    print('finished state\t\tclick(' + str(x) + ', ' + str(y) + ')')
                    # x,y (990, 169)   r,g,b (255, 253, 58)
                    if checkcolor(990, 169) == (255, 253, 58):
                        randtimesleep(0.5)
                        # x1,y1 (1017, 529)  x2,y2 (1522, 623)
                        x, y = randclick(1017, 529, 1522, 623)
                        print('\tdefeated\tclick(' + str(x) + ', ' + str(y) + ')') 
                        return 1
                    # x,y (914, 164)   r,g,b (255, 255, 49)
                    if checkcolor(914, 164) == (255, 255, 49):
                        randtimesleep(0.5)
                        # x1,y1 = (1352, 473)   x2,y2 = (1536, 596)
                        x, y = randclick(1352, 473, 1536, 596)
                        print('\topen reward\tclick(' + str(x) + ', ' + str(y) + ')')
                        randtimesleep(1.5)
                        # x1,y1 = (871, 757)   x2,y2 = (1004, 832)
                        x, y = randclick(871, 757, 1004, 832)
                        print('\tclaim reward\tclick(' + str(x) + ', ' + str(y) + ')')
                    randtimesleep(0.5)
                    # x1,y1 = (473, 533)   x2,y2 = (782, 621)
                    x, y = randclick(473, 533, 782, 621)
                    print('\tnext state\tclick(' + str(x) + ', ' + str(y) + ')')
                    break
                time.sleep(3)
        randtimesleep(0.5)


def oneStupgrade():
    round = 1
    print("oneSupgrade will start in 3 sec")
    time.sleep(3)
    print("oneSupgrade is starting")
    while keyboard.is_pressed('left alt') == False:  
        randtimesleep(0.5)
        # x,y (1162, 907)   r,g,b (248, 198, 104)
        if checkcolor(1162, 907) == (248, 198, 104):
            print("round " + str(round))
            randtimesleep(0.25)
            # x1,y1 = (1129, 877)   x2,y2 = (1200, 948)
            randclick(1129, 877, 1200, 948)
            print('\t1st open storage')
            randtimesleep(0.25)
            if round == 1:
                # x,y (510, 218)   r,g,b (248, 233, 173)
                if checkcolor(510, 218) != (248, 233, 173):
                    randtimesleep(0.25)
                    # x1,y1 = (376, 208)   x2,y2 = (643, 264)
                    randclick(376, 208, 643, 264)
                    randtimesleep(0.25)
                    # x1,y1 = (388, 439)   x2,y2 = (599, 500)
                    randclick(388, 439, 599, 500)
                    randtimesleep(0.25)
                    print('\tchoose category')
            # x1,y1 = (392, 310)   x2,y2 = (495, 410)
            randclick(392, 310, 495, 410)
            randtimesleep(0.25)
            print('\tpick 1st monster')
            while True:
                # x,y (940, 908)   r,g,b (248, 233, 173)
                if checkcolor(940, 908) == (248, 233, 173):
                    # x1,y1 = (828, 874)   x2,y2 = (1044, 932)
                    randclick(828, 874, 1044, 932)
                    randtimesleep(0.25)
                    print('\tconfirm 1st monster')
                    while True:
                        # x,y (1162, 907)   r,g,b (248, 198, 104)
                        if checkcolor(1162, 907) == (248, 198, 104):
                            # x1,y1 = (1129, 877)   x2,y2 = (1200, 948)
                            randclick(1129, 877, 1200, 948)
                            randtimesleep(0.25)
                            print('\t2nd open storage')
                            # x1,y1 (179, 455)  x2,y2 (343, 509)
                            randclick(179, 455, 343, 509)
                            randtimesleep(0.25)
                            # x1,y1 (383, 301)  x2,y2 (489, 405)
                            randclick(383, 301, 489, 405)
                            randtimesleep(0.25)
                            print('\tpick 2nd monster')
                            while True:
                                # x,y (940, 908)   r,g,b (248, 233, 173)
                                if checkcolor(940, 908) == (248, 233, 173):
                                    # x1,y1 = (828, 874)   x2,y2 = (1044, 932)
                                    randclick(828, 874, 1044, 932)
                                    randtimesleep(0.25)  
                                    print('\tconfirm 2nd monster')
                                    while True:
                                        # x,y (685, 950)   r,g,b (81, 180, 248)
                                        if checkcolor(685, 950) == (78, 177, 248):
                                            # x1,y1 (607, 866)  x2,y2 (870, 971)
                                            randclick(607, 866, 870, 971)
                                            randtimesleep(0.5)  
                                            print('\tconfirm upgrade')
                                            while True:
                                                # x,y (794, 640)   r,g,b (248, 233, 173)
                                                if checkcolor(794, 640) == (248, 233, 173):
                                                    # x1,y1 (679, 592)  x2,y2 (892, 673)
                                                    randclick(679, 592, 892, 673)
                                                    randtimesleep(1)
                                                    # x1,y1 (1626, 950)  x2,y2 (1713, 987)
                                                    randclick(1626, 950, 1713, 987)     
                                                    randtimesleep(1.5)  
                                                    print('\tskip')  
                                                    # x1,y1 (1449, 861)  x2,y2 (1600, 870)
                                                    randclick(1449, 861, 1600, 870)
                                                    randtimesleep(0.5)
                                                    # x,y (1548, 869)   r,g,b (208, 171, 101)
                                                    if checkcolor(1548, 869) != (208, 171, 101):
                                                        # x1,y1 (1449, 861)  x2,y2 (1600, 870)
                                                        randclick(1449, 861, 1600, 870)
                                                        randtimesleep(0.1)
                                                        randclick(1449, 861, 1600, 870)
                                                        print('\tskill up\tTRUE')
                                                        time.sleep(0.1)
                                                    print('\tend')
                                                    round += 1
                                                    break
                                            break
                                    break
                            break
                    break


def breakEssence(max):
    round = 1
    print("breakEssence will start begin when you press 's'")
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            start_time = time.strftime("%H:%M:%S", time.localtime())
            x, y = pyautogui.position()
            randtimesleep(1)
            randclick(x, y)
            while keyboard.is_pressed('left alt') == False and round <= max/5:
                print("\tround " + str(round))
                randtimesleep(0.35)
                # x,y (730, 946)   r,g,b (93, 193, 247)
                if checkcolor(730, 946) == (93, 193, 247):
                    # x1,y1 (659, 863)  x2,y2 (930, 972)
                    randclick(659, 863, 930, 972)
                    randtimesleep(0.65)
                    # x1,y1 (677, 591)  x2,y2 (897, 674)
                    randclick(677, 591, 897, 674)
                    randtimesleep(3.5)
                    # x1,y1 (833, 595)  x2,y2 (1050, 671)
                    randclick(833, 595, 1050, 671)
                    round += 1
            finish_time = time.strftime("%H:%M:%S", time.localtime())
            print("start time:\t", start_time)
            print("finish time:\t", finish_time)
            break


def summon100x(amount):
    currentamount = 0
    print("summon 10 times will start when press 's'")
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            start_time = time.strftime("%H:%M:%S", time.localtime())
            while keyboard.is_pressed('left alt') == False and amount > currentamount:
                randtimesleep(0.5)
                # x,y (630, 806)   r,g,b (254, 255, 26)	
                if checkcolor(630, 806) != (254, 255, 26):
                    # x1,y1 (613, 787)  x2,y2 (643, 810)	
                    randclick(613, 787, 643, 810)
                    print("\tenable 100x summon")
                    randtimesleep(0.5)
                # x1,y1 (609, 867)  x2,y2 (871, 970)	
                randclick(609, 867, 871, 970)
                print("\tsummon")
                randtimesleep(0.5)
                # x,y (1032, 397)   r,g,b (226, 197, 130)	
                if checkcolor(1032, 397) == (226, 197, 130):
                    # x1,y1 (839, 598)  x2,y2 (1032, 667)	
                    randclick(839, 598, 1032, 667)
                    print("\tout of scroll")
                    return 0
                # x,y (771, 408)   r,g,b (255, 219, 51)	
                if checkcolor(771, 408) == (255, 219, 51):
                    # x1,y1 (781, 481)  x2,y2 (807, 502)	
                    randclick(781, 481, 807, 502)
                    print("\tdisable warning")
                    randtimesleep(0.5)
                    # x1,y1 (676, 596)  x2,y2 (892, 672)	
                    randclick(676, 596, 892, 672)
                    print("\tconfirm disable warning")
                    randtimesleep(0.5)
                # x,y (911, 121)   r,g,b (255, 254, 67)	
                while checkcolor(911, 121) != (255, 254, 67):
                    # x1,y1 (1614, 944)  x2,y2 (1714, 985)	
                    randclick(1614, 944, 1714, 985)
                    print("\tskip")
                    randtimesleep(0.5)
                # x1,y1 (823, 920)  x2,y2 (1053, 985)	
                randclick(823, 920, 1053, 985)
                print("\tcomfirm summon result")
                
    finish_time = time.strftime("%H:%M:%S", time.localtime())
    print("\n" + str(currentamount) + " rounds")
    print("start time:\t", start_time)
    print("finish time:\t", finish_time)


def autoFarmNoSell():
    currentamount = 0
    print("auto farm untill energy is out will start when press 's'")
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            start_time = time.strftime("%H:%M:%S", time.localtime())
            start_round_time = time.strftime("%H:%M:%S", time.localtime())
            print("\tstarts round", currentamount+1)
            print("\tstart round time", start_round_time)
            # x1,y1 (1453, 736)  x2,y2 (1646, 815)	
            randclick(1453, 736, 1646, 815)
            randtimesleep(0.5)
            while keyboard.is_pressed('left alt') == False:
                if checkcolor(939, 318) == (244, 243, 198):
                    # x1,y1 (743, 435)  x2,y2 (1169, 664)	
                    randclick(743, 435, 1169, 664)
                # x,y (944, 882)   r,g,b (247, 245, 245)	
                if checkcolor(944, 882) == (247, 245, 245):
                    currentamount += 1
                    finish_round_time = time.strftime("%H:%M:%S", time.localtime())
                    print("\tfinished round", currentamount)
                    print("\tfinish round time", finish_round_time)
                    # x1,y1 (873, 863)  x2,y2 (1118, 924)	
                    randclick(873, 863, 1118, 924)
                    print("\treplay")
                    randtimesleep(0.5)
                    # x1,y1 (1453, 736)  x2,y2 (1646, 815)	
                    randclick(1453, 736, 1646, 815)
                    start_round_time = time.strftime("%H:%M:%S", time.localtime())
                    print("\tstarts round", currentamount+1)
                    print("\tstart round time", start_round_time)
                    randtimesleep(0.5)
                    # x,y (1217, 728)   r,g,b (89, 62, 35)		
                    if checkcolor(1217, 728) == (89, 62, 35):
                        # x1,y1 (685, 660)  x2,y2 (871, 718)	
                        randclick(685, 660, 871, 718)
                        randtimesleep(0.5)
                    # x,y (827, 663)   r,g,b (248, 233, 173)	
                    if checkcolor(827, 663) == (248, 233, 173):
                        print("exit\tout of energy")
                        break
                time.sleep(5)
            break
    finish_time = time.strftime("%H:%M:%S", time.localtime())
    print("\n" + str(currentamount) + " rounds")
    print("start time:\t", start_time)
    print("finish time:\t", finish_time)
    
    
def autoFarmRunes():
    currentamount = 0
    print("auto Runes farm untill energy is out will start when press 's'")
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            start_time = time.strftime("%H:%M:%S", time.localtime())
            start_round_time = time.strftime("%H:%M:%S", time.localtime())
            print("\tstarts round", currentamount+1)
            print("\tstart round time", start_round_time)
            # x1,y1 (1453, 736)  x2,y2 (1646, 815)	
            randclick(1453, 736, 1646, 815)
            randtimesleep(0.5)
            while keyboard.is_pressed('left alt') == False:
                # x,y (939, 318)   r,g,b (244, 243, 198)	
                if checkcolor(939, 318) == (244, 243, 198):
                    # x1,y1 (743, 435)  x2,y2 (1169, 664)	
                    randclick(743, 435, 1169, 664)
                # x,y (944, 882)   r,g,b (247, 245, 245)	
                if checkcolor(944, 882) == (247, 245, 245):
                    currentamount += 1
                    finish_round_time = time.strftime("%H:%M:%S", time.localtime())
                    print("\tfinished round", currentamount)
                    print("\tfinish round time", finish_round_time)
                    # x1,y1 (1459, 893)  x2,y2 (1720, 921)	
                    randclick(1459, 893, 1720, 921)
                    print("\tbegin sell item")
                    randtimesleep(0.5)
                    # x1,y1 (1323, 895)  x2,y2 (1490, 936)	
                    randclick(1323, 895, 1490, 936)
                    print("\tselect sell")
                    randtimesleep(0.5)
                    # x,y (897, 615)   r,g,b (248, 233, 173)	
                    if checkcolor(897, 615) == (248, 233, 173):
                        # x1,y1 (837, 600)  x2,y2 (1035, 671)	
                        randclick(837, 600, 1035, 671)
                        randtimesleep(0.5)
                        # x1,y1 (1550, 893)  x2,y2 (1734, 949)	
                        randclick(1550, 893, 1734, 949)
                        randtimesleep(0.5)
                        print("\tnothing to sell")
                    else:
                        # x1,y1 (840, 597)  x2,y2 (882, 666)	
                        randclick(840, 597, 882, 666)
                        randtimesleep(1)
                        # x,y (996, 355)   r,g,b (226, 197, 130)	
                        if checkcolor(996, 355) == (226, 197, 130):
                            # x1,y1 (678, 656)  x2,y2 (881, 732)	
                            randclick(678, 656, 881, 732)
                            randtimesleep(0.5)
                            print("\tsell legend rune")
                        # x,y (1045, 375)   r,g,b (226, 197, 130)	
                        if checkcolor(1045, 375) == (226, 197, 130):
                            # x1,y1 (674, 596)  x2,y2 (885, 671)	
                            randclick(674, 596, 885, 671)
                            randtimesleep(0.5)
                            print("\tsell high grade gem")
                    print("\tconfirm sell")
                    randtimesleep(0.5)
                    # x,y (1120, 714)   r,g,b (216, 203, 163)	
                    if checkcolor(1120, 714) == (216, 203, 163):
                        print("exit\tlevel already max")
                        break
                    # x1,y1 (873, 863)  x2,y2 (1118, 924)	
                    randclick(873, 863, 1118, 924)
                    print("\treplay")
                    randtimesleep(0.5)
                    # x1,y1 (1453, 736)  x2,y2 (1646, 815)	
                    randclick(1453, 736, 1646, 815)
                    start_round_time = time.strftime("%H:%M:%S", time.localtime())
                    print("\tstarts round", currentamount+1)
                    print("\tstart round time", start_round_time)
                    randtimesleep(0.5)
                    # x,y (1217, 728)   r,g,b (89, 62, 35)		
                    if checkcolor(1217, 728) == (89, 62, 35):
                        # x1,y1 (685, 660)  x2,y2 (871, 718)	
                        randclick(685, 660, 871, 718)
                        randtimesleep(0.5)
                    # x,y (827, 663)   r,g,b (248, 233, 173)	
                    if checkcolor(827, 663) == (248, 233, 173):
                        print("exit\tout of energy")
                        break
                time.sleep(5)
            break
    finish_time = time.strftime("%H:%M:%S", time.localtime())
    print("\n" + str(currentamount) + " rounds")
    print("start time:\t", start_time)
    print("finish time:\t", finish_time)    


def autoFarmGrindStone():
    currentamount = 0
    print("auto Grind Stone farm untill energy is out will start when press 's'")
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            start_time = time.strftime("%H:%M:%S", time.localtime())
            start_round_time = time.strftime("%H:%M:%S", time.localtime())
            print("\tstarts round", currentamount+1)
            print("\tstart round time", start_round_time)
            # x1,y1 (1474, 904)  x2,y2 (1764, 998)	
            randclick(1474, 904, 1764, 998)
            randtimesleep(0.5)
            while keyboard.is_pressed('left alt') == False:
                if checkcolor(939, 318) == (244, 243, 198):
                    # x1,y1 (743, 435)  x2,y2 (1169, 664)	
                    randclick(743, 435, 1169, 664)
                # x,y (944, 882)   r,g,b (247, 245, 245)	
                if checkcolor(944, 882) == (247, 245, 245):
                    currentamount += 1
                    finish_round_time = time.strftime("%H:%M:%S", time.localtime())
                    print("\tfinished round", currentamount)
                    print("\tfinish round time", finish_round_time)
                    # x1,y1 (1459, 893)  x2,y2 (1720, 921)	
                    randclick(1459, 893, 1720, 921)
                    print("\tbegin sell item")
                    randtimesleep(0.5)
                    # x1,y1 (1323, 895)  x2,y2 (1490, 936)	
                    randclick(1323, 895, 1490, 936)
                    print("\tselect sell")
                    randtimesleep(0.5)
                    # x,y (897, 615)   r,g,b (248, 233, 173)	
                    if checkcolor(897, 615) == (248, 233, 173):
                        # x1,y1 (837, 600)  x2,y2 (1035, 671)	
                        randclick(837, 600, 1035, 671)
                        randtimesleep(0.5)
                        # x1,y1 (1550, 893)  x2,y2 (1734, 949)	
                        randclick(1550, 893, 1734, 949)
                        randtimesleep(0.5)
                        print("\tnothing to sell")
                    else:
                        # x1,y1 (840, 597)  x2,y2 (882, 666)	
                        randclick(840, 597, 882, 666)
                        randtimesleep(1)
                        # x,y (1045, 375)   r,g,b (226, 197, 130)	
                        if checkcolor(1045, 375) == (226, 197, 130):
                            # x1,y1 (674, 596)  x2,y2 (885, 671)	
                            randclick(674, 596, 885, 671)
                            randtimesleep(1)
                            print("\tsell high grade gem")
                    print("\tconfirm sell")
                    randtimesleep(0.5)
                    # x1,y1 (873, 863)  x2,y2 (1118, 924)	
                    randclick(873, 863, 1118, 924)
                    print("\treplay")
                    randtimesleep(1)
                    # x1,y1 (1478, 854)  x2,y2 (1759, 970)	
                    randclick(1478, 854, 1759, 970)
                    start_round_time = time.strftime("%H:%M:%S", time.localtime())
                    print("\tstarts round", currentamount+1)
                    print("\tstart round time", start_round_time)
                    randtimesleep(0.5)
                    # x,y (1217, 728)   r,g,b (89, 62, 35)		
                    if checkcolor(1217, 728) == (89, 62, 35):
                        # x1,y1 (685, 660)  x2,y2 (871, 718)	
                        randclick(685, 660, 871, 718)
                        randtimesleep(0.5)
                    # x,y (827, 663)   r,g,b (248, 233, 173)	
                    if checkcolor(827, 663) == (248, 233, 173):
                        print("exit\tout of energy")
                        break
                time.sleep(5)
            break
    finish_time = time.strftime("%H:%M:%S", time.localtime())
    print("\n" + str(currentamount) + " rounds")
    print("start time:\t", start_time)
    print("finish time:\t", finish_time)        
    
    
def upgrade(max):
    currentamount = 0
    print("auto farm untill energy is out will start when press 's'")
    while keyboard.is_pressed('left alt') == False:
        if keyboard.is_pressed('s') == True:
            x, y = pyautogui.position()
            while keyboard.is_pressed('left alt') == False and max > currentamount:
                # x,y (1491, 909)   r,g,b (91, 191, 250)	
                if checkcolor(1491, 909) == (91, 191, 250):
                    randclick(x-25, y-25, x+25, y+25)
                    randtimesleep(0.25)
                    # x1,y1 (703, 262)  x2,y2 (732, 285)	
                    randclick(703, 262, 732, 285)
                    randtimesleep(0.5)
                    # x1,y1 (603, 870)  x2,y2 (862, 967)	
                    randclick(603, 870, 862, 967)
                    randtimesleep(0.5)
                    # x1,y1 (688, 599)  x2,y2 (879, 671)	
                    randclick(688, 599, 879, 671)
                    randtimesleep(0.5)
                    while keyboard.is_pressed('left alt') == False and checkcolor(1433, 816) != (248, 233, 173):
                        # x1,y1 (1617, 949)  x2,y2 (1718, 987)	
                        randclick(1617, 949, 1718, 987)
                        randtimesleep(0.25)
                    print("\tskip")
                    randtimesleep(0.5)
                    # x1,y1 (1377, 803)  x2,y2 (1590, 870)
                    randclick(1377, 803, 1590, 870)
                    randtimesleep(0.5)
                    print("\tOk")
                    currentamount += 1 
            return 0
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Quality of Life in SMW Functions**

# %% [markdown]
# Auto Rta

# %%
autoRTA(30)

# %% [markdown]
# Auto Special Leauge

# %%
autoRTAsl(30)

# %% [markdown]
# Auto TOA

# %%
autoTOA()

# %% [markdown]
# Auto Farm with no selling

# %%
autoFarmNoSell()
#exitgame()

# %% [markdown]
# Auto Farm runes

# %%
autoFarmRunes()
exitgame()

# %% [markdown]
# Auto Farm Grind Stone

# %%
autoFarmGrindStone()
exitgame()

# %% [markdown]
# Auto One Star Upgrade

# %%
oneStupgrade()

# %% [markdown]
# Brake / Fusion Essence

# %%
breakEssence(10)

# %% [markdown]
# Auto Summon Monster 100x

# %%
summon100x(2000)

# %% [markdown]
# Upgrade monster

# %%
upgrade(3)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Debugging Tools**

# %% [markdown]
# Set Position of Cursor

# %%
win32api.SetCursorPos((1010, 880))

# %% [markdown]
# Check Pixel's Information of Position

# %%
checkPosition(1010, 880)

# %% [markdown]
# Check Mouse Position Pixel's Information

# %%
checkClick()

# %% [markdown]
# Continuous Click

# %%
continuousclick()

# %%
while keyboard.is_pressed('left alt') == False:
    # x,y (317, 207)   r,g,b (13, 110, 127)	
    click(317, 207)
    time.sleep(0.5)
    # x,y (1671, 720)   r,g,b (43, 24, 7)	
    click(1671, 720)
    time.sleep(0.5)
    # x,y (1200, 503)   r,g,b (41, 23, 13)	
    click(1200, 503)
    time.sleep(0.5)
    # x,y (1167, 400)   r,g,b (128, 101, 85)	
    click(1167, 400)
    time.sleep(0.5)
    # x,y (937, 928)   r,g,b (248, 233, 173)	
    click(937, 928)
    time.sleep(0.5)
    # x,y (950, 843)   r,g,b (157, 137, 88)	
    click(950, 843)
    time.sleep(0.5)

# %%
SETTINGS = {
    # 'start_b': {'pos': (1670, 496), 'colors': (255, 250, 201)},
    'out_of_ticket': {'pos': (779, 397), 'color': (209, 180, 119)},
    # 'autoplay_b': {'pos': (172, 1019), 'color': (255, 255, 255)},
    'give_up': {'pos': (897, 615), 'color': (248, 233, 173)},
    # 'match_finish_ic': {'pos': (447, 755), 'colors': (204, 102, 16)}.

    # 'click_start_b': {'area': ((1557, 464), (1842, 534))}
    'randclick_out_of_ticket': {'area': ((831, 595), (1041, 672))},
    # 'click_autoplay': {'area': ((149, 997), (197, 1042))}
    'randclick_give_up': {'area': ((880, 595), (1004, 671))},
    # 'click_finish': {'area': ((1585, 738), (1878, 883))}
}

# %%
while keyboard.is_pressed('left alt') == False:
    if keyboard.is_pressed('s') == True:
        randclick(219, 737, 487, 827)
        time.sleep(0.5)
        while keyboard.is_pressed('left alt') == False:
            # x,y (279, 500)   r,g,b (192, 128, 137
            if (checkcolor(279, 500) == (192, 128, 137)) and (checkcolor(575, 566) == (227, 232, 227)):
                break
            else:
                # x1,y1 (219, 737)  x2,y2 (487, 827)	
                randclick(219, 737, 487, 827)
                time.sleep(0.5)

# %%
import keyboard

i = 0
j = 0
while not keyboard.is_pressed('right alt'):
    i += 1
    print('start round', i )
    start_round_time = time.strftime("%H:%M:%S", time.localtime())
    # x, y (1459, 951)   r, g, b (255, 255, 255)
    while not checkcolor(1459, 951) == (255, 255, 255):
        time.sleep(0.5)
    click(1459, 951)
    # x, y (1727, 122)   r, g, b (201, 201, 201)
    while not checkcolor(1727, 122) == (201, 201, 201):
        time.sleep(0.5)
    click(1727, 122)
    # x, y (1487, 942)   r, g, b (255, 255, 255)
    while not checkcolor(1487, 942) == (255, 255, 255):
        time.sleep(0.5)
    click(1487, 942)
    # x, y (1399, 827)   r, g, b (244, 244, 244)
    while not checkcolor(1399, 827) == (244, 244, 244):
        time.sleep(0.5)
    click(1399, 827)
    while not checkcolor(1711, 132) == (170, 10, 9):
        j += 1
        # x,y (115, 87)   r,g,b (255, 255, 255)	
        while not checkcolor(115, 87) == (255, 255, 255):
            click(1768, 81)
            time.sleep(0.5)
        
        time.sleep(0.5)
        if checkcolor(1711, 132) != (170, 10, 9):
            # x, y (1691, 114)   r, g, b (43, 43, 43)
            while not checkcolor(1691, 114) == (43, 43, 43):
                time.sleep(0.5)
            click(1691, 114)
            time.sleep(0.5)
            # x, y (1217, 728)   r, g, b (122, 31, 31)
            while not checkcolor(1217, 728) == (122, 31, 31):
                time.sleep(0.5)
            click(1217, 728)
        print('\tfinished day', j)
        time.sleep(0.5)
        

    # x,y (114, 86)   r,g,b (255, 255, 255)	
    while not checkcolor(114, 86) == (255, 255, 255):
        time.sleep(0.5)
    click(114, 86)
    # x,y (1138, 941)   r,g,b (66, 22, 21)	
    while not checkcolor(1138, 941) == (66, 22, 21):
        time.sleep(0.5)
    click(1138, 941)
    # x,y (1217, 728)   r,g,b (122, 31, 31)	
    while not checkcolor(1217, 728) == (122, 31, 31):
        time.sleep(0.5)
    click(1217, 728)
    # x,y (1644, 898)   r,g,b (215, 213, 97)	
    while not checkcolor(1644, 898) == (215, 213, 97):
        time.sleep(0.5)
    click(1644, 898)
    # x,y (1701, 875)   r,g,b (215, 213, 97)	
    while not checkcolor(1701, 875) == (215, 213, 97):
        time.sleep(0.5)
    click(1701, 875)
    # x,y (931, 436)   r,g,b (251, 198, 6)	
    while not checkcolor(931, 436) == (251, 198, 6):   
        time.sleep(0.5)
    click(954, 799)
    j = 0
    print('fnished round', i )
    finish_round_time = time.strftime("%H:%M:%S", time.localtime())
    print("start round time:\t", start_round_time)
    print("finish round time:\t", finish_round_time)

# %%
import keyboard

i = 0
j = 0
while not keyboard.is_pressed('right alt'):
    # --------------- INTRO SECTION ---------------
    # if keyboard.is_pressed('a'):
    i += 1
    print('start round', i )
    start_round_time = time.strftime("%H:%M:%S", time.localtime())
    print('INTRO SECTION')
    # x,y (1473, 935)   r,g,b (216, 216, 109)	
    while not checkcolor(1473, 935) == (216, 216, 109):
        time.sleep(0.5)
    click(1473, 935)
    # x,y (899, 491)   r,g,b (12, 152, 134)	
    while not checkcolor(899, 491) == (12, 152, 134):
        click(1473, 935)
        time.sleep(0.5)
    click(899, 491)
    # x,y (1608, 826)   r,g,b (215, 215, 215)	
    while not checkcolor(1608, 826) == (215, 215, 215):
        click(899, 491)
        time.sleep(0.5)
    click(1608, 826)
    # x,y (158, 93)   r,g,b (171, 170, 167)	
    while not checkcolor(158, 93) == (171, 170, 167):
        click(1608, 826)
        time.sleep(0.5)
    time.sleep(0.5)
    # x,y (171, 106)   r,g,b (216, 216, 108)	
    while not checkcolor(171, 106) == (216, 216, 108):
        # x1,y1 (1320, 629)  x2,y2 (1779, 671)	
        randclick(1320, 629, 1779, 671)
        time.sleep(0.2)
    click(141, 100)
    # x,y (1085, 701)   r,g,b (198, 196, 98)	
    while not checkcolor(1085, 701) == (198, 196, 98):
        click(141, 100)
        time.sleep(1)
    click(1085, 701)
    
    # --------------- GAMEPALY SECTION ---------------
    # x,y (899, 493)   r,g,b (12, 152, 134)	
    # if keyboard.is_pressed('s'):
    print('GAMEPALY SECTION')
    while not checkcolor(899, 493) == (12, 152, 134):
        time.sleep(0.5)
    dragclick(101, 412, 102, 551)
    # x,y (434, 443)   r,g,b (254, 254, 254)	
    while not checkcolor(434, 443) == (254, 254, 254):
        time.sleep(0.5)
    click(434, 443)
    # x,y (1669, 828)   r,g,b (223, 223, 87)	
    while not checkcolor(1669, 828) == (223, 223, 87):
        click(434, 443)
        time.sleep(0.5)
    click(1669, 828)
    # x,y (1650, 970)   r,g,b (223, 223, 87)	
    while not checkcolor(1650, 970) == (223, 223, 87):
        click(1669, 828)
        time.sleep(0.5)
    click(1650, 970)
    # x,y (1532, 706)   r,g,b (209, 37, 36)	
    while not checkcolor(1532, 706) == (209, 37, 36):
        click(1650, 970)
        time.sleep(0.5)
    click(1532, 706)
    # x,y (171, 106)   r,g,b (216, 216, 108)	
    while not checkcolor(171, 106) == (216, 216, 108):
        click(1532, 706)
        time.sleep(0.5)
    click(141, 100)
    # x,y (1085, 701)   r,g,b (198, 196, 98)	
    while not checkcolor(1085, 701) == (198, 196, 98):
        click(141, 100)
        time.sleep(1)
    click(1085, 701)
    print('d1')
    
    # x,y (369, 768)   r,g,b (255, 255, 255)	
    while not checkcolor(369, 768) == (255, 255, 255):
        click(659, 724)
        time.sleep(0.5)
    click(369, 768)
    # x,y (1669, 828)   r,g,b (223, 223, 87)	
    while not checkcolor(1669, 828) == (223, 223, 87):
        click(369, 768)
        time.sleep(0.5)
    click(1669, 828)
    # x,y (1650, 970)   r,g,b (223, 223, 87)	
    while not checkcolor(1650, 970) == (223, 223, 87):
        click(1669, 828)
        time.sleep(0.5)
    click(1650, 970)
    # x,y (1532, 706)   r,g,b (209, 37, 36)	
    while not checkcolor(1532, 706) == (209, 37, 36):
        click(1650, 970)
        time.sleep(0.5)
    click(1532, 706)
    # x,y (171, 106)   r,g,b (216, 216, 108)	
    while not checkcolor(171, 106) == (216, 216, 108):
        click(1532, 706)
        time.sleep(0.5)
    click(141, 100)
    # x,y (1085, 701)   r,g,b (198, 196, 98)	
    while not checkcolor(1085, 701) == (198, 196, 98):
        click(141, 100)
        time.sleep(1)
    click(1085, 701)
    print('d2')
    
    print('skipday')
    # x,y (1698, 163)   r,g,b (255, 255, 255)	
    while not checkcolor(1698, 163) == (255, 255, 255):
        click(659, 724)
        time.sleep(0.5)
    click(1698, 163)
    # x,y (940, 873)   r,g,b (87, 80, 70)	
    while not checkcolor(940, 873) == (87, 80, 70):
        click(1698, 163)
        time.sleep(0.5)
    click(940, 873)
    print('skip2')
    # x,y (1681, 146)   r,g,b (216, 215, 105)	
    while not checkcolor(1681, 146) == (216, 215, 105):
        click(940, 873)
        time.sleep(0.5)
    click(1680, 145)
    # x,y (1736, 265)   r,g,b (253, 253, 253)	
    while not checkcolor(1736, 265) == (253, 253, 253):
        click(1680, 145)
        time.sleep(0.5)
    click(1736, 265)
    # x,y (1234, 697)   r,g,b (198, 196, 98)	
    while not checkcolor(1234, 697) == (198, 196, 98):
        click(1736, 265)
        time.sleep(0.5)
    click(1234, 697)
    print('preskip3')
    # x,y (1698, 163)   r,g,b (255, 255, 255)	
    while not checkcolor(1698, 163) == (255, 255, 255):
        click(1234, 697)
        time.sleep(0.5)
    click(1698, 163)
    # x,y (940, 873)   r,g,b (87, 80, 70)	
    while not checkcolor(940, 873) == (87, 80, 70):
        click(1698, 163)
        time.sleep(0.5)
    click(940, 873)
    print('skip3')

    print('d3')
    # x,y (1416, 506)   r,g,b (255, 255, 255)	
    while not checkcolor(1416, 506) == (255, 255, 255):
        click(940, 873)
        time.sleep(0.5)
    click(369, 768)
    # x,y (1669, 828)   r,g,b (223, 223, 87)	
    while not checkcolor(1669, 828) == (223, 223, 87):
        click(369, 768)
        time.sleep(0.5)
    click(1669, 828)
    # x,y (1435, 963)   r,g,b (255, 255, 255)	
    while not checkcolor(1435, 963) == (255, 255, 255):
        click(1669, 828)
        time.sleep(0.5)
    click(1435, 963)
    # x,y (1351, 840)   r,g,b (253, 253, 253)	
    while not checkcolor(1351, 840) == (253, 253, 253):
        click(1435, 963)
        time.sleep(0.5)
    for m in range(5): 
        click(1351, 840)
        time.sleep(0.2)
    # x,y (1460, 821)   r,g,b (249, 248, 70)	
    while not checkcolor(1460, 821) == (249, 248, 70):
        click(1351, 840)
        time.sleep(0.5)
    click(1460, 821)
    # x,y (936, 582)   r,g,b (255, 255, 171)	
    while not checkcolor(936, 582) == (255, 255, 171):
        click(1460, 821)
        time.sleep(0.5)
    click(962, 680)
    # x,y (183, 74)   r,g,b (30, 30, 30)	
    while not checkcolor(183, 74) == (30, 30, 30):
        click(962, 680)
        time.sleep(0.5)
    click(183, 74)
    # x,y (1650, 970)   r,g,b (223, 223, 87)	
    while not checkcolor(1650, 970) == (223, 223, 87):
        click(1669, 828)
        time.sleep(0.5)
    click(1650, 970)
    # x,y (1532, 706)   r,g,b (209, 37, 36)	
    while not checkcolor(1532, 706) == (209, 37, 36):
        click(1650, 970)
        time.sleep(0.5)
    click(1532, 706)
    # x,y (171, 106)   r,g,b (216, 216, 108)	
    while not checkcolor(171, 106) == (216, 216, 108):
        click(1532, 706)
        time.sleep(0.5)
    click(141, 100)
    # x,y (1085, 701)   r,g,b (198, 196, 98)	
    while not checkcolor(1085, 701) == (198, 196, 98):
        click(141, 100)
        time.sleep(1)
    click(1085, 701)
    
    # x,y (1681, 146)   r,g,b (216, 215, 105)	
    while not checkcolor(1681, 146) == (216, 215, 105):
        click(1085, 701)
        time.sleep(0.5)
    click(1680, 145)
    # x,y (1736, 265)   r,g,b (253, 253, 253)	
    while not checkcolor(1736, 265) == (253, 253, 253):
        click(1680, 145)
        time.sleep(0.5)
    click(1736, 265)
    # x,y (1234, 697)   r,g,b (198, 196, 98)	
    while not checkcolor(1234, 697) == (198, 196, 98):
        click(1736, 265)
        time.sleep(0.5)
    click(1234, 697)
    print('preskip3')
    # x,y (1698, 163)   r,g,b (255, 255, 255)	
    while not checkcolor(1698, 163) == (255, 255, 255):
        click(1234, 697)
        time.sleep(0.5)
    click(1698, 163)
    # x,y (942, 844)   r,g,b (215, 215, 105)	
    while not checkcolor(942, 844) == (215, 215, 105):
        click(1698, 163)
        time.sleep(0.5)
    click(942, 844)
    print('skip3')

    # --------------- END SECTION ---------------
    print('END SECTION')
    # if keyboard.is_pressed('d'):
    # x,y (1473, 964)   r,g,b (182, 181, 179)
